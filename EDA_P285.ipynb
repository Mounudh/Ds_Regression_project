# %%
# Import Necessary library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("/content/Regrerssion_energy_production_data (2).csv")

# %%
data
# Out:
#       temperature  exhaust_vacuum  amb_pressure  r_humidity  energy_production
# 0            9.59           38.56       1017.01       60.10             481.30
# 1           12.04           42.34       1019.72       94.67             465.36
# 2           13.87           45.08       1024.42       81.69             465.48
# 3           13.72           54.30       1017.89       79.08             467.05
# 4           15.14           49.64       1023.78       75.00             463.58
# ...           ...             ...           ...         ...                ...
# 9563        17.10           49.69       1005.53       81.82             457.32
# 9564        24.73           65.34       1015.42       52.80             446.92
# 9565        30.44           56.24       1005.19       56.24             429.34
# 9566        23.00           66.05       1020.61       80.29             421.57
# 9567        17.75           49.25       1020.86       63.67             454.41
#
# [9568 rows x 5 columns]

# %%
data.dtypes
# Out:
# temperature          float64
# exhaust_vacuum       float64
# amb_pressure         float64
# r_humidity           float64
# energy_production    float64
# dtype: object

# %%
data.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of       temperature  exhaust_vacuum  amb_pressure  r_humidity  energy_production
# 0           False           False         False       False              False
# 1           False           False         False       False              False
# 2           False           False         False       False              False
# 3           False           False         False       False              False
# 4           False           False         False       False              False
# ...           ...             ...           ...         ...                ...
# 9563        False           False         False       False              False
# 9564        False           False         False       False              False
# 9565        False           False         False       False              False
# 9566        False           False         False       False              False
# 9567        False           False         False       False              False
#
# [9568 rows x 5 columns]>

# %%
#Showing first 5 rows of data
data.head()
# Out:
#    temperature  exhaust_vacuum  amb_pressure  r_humidity  energy_production
# 0         9.59           38.56       1017.01       60.10             481.30
# 1        12.04           42.34       1019.72       94.67             465.36
# 2        13.87           45.08       1024.42       81.69             465.48
# 3        13.72           54.30       1017.89       79.08             467.05
# 4        15.14           49.64       1023.78       75.00             463.58

# %%
#Showing last 10 rows of data
data.tail(10)
# Out:
#       temperature  exhaust_vacuum  amb_pressure  r_humidity  energy_production
# 9558        11.81           40.75       1016.13       84.14             477.22
# 9559        14.73           40.35       1011.15       65.20             470.03
# 9560        25.84           69.14       1009.22       88.47             431.35
# 9561        21.90           63.13       1011.54       81.83             447.40
# 9562        21.85           63.86       1020.16       68.84             445.62
# 9563        17.10           49.69       1005.53       81.82             457.32
# 9564        24.73           65.34       1015.42       52.80             446.92
# 9565        30.44           56.24       1005.19       56.24             429.34
# 9566        23.00           66.05       1020.61       80.29             421.57
# 9567        17.75           49.25       1020.86       63.67             454.41

# %%
#number of rows and columns
data.shape
# Out:
# (9568, 5)

# %%
#checking the null values
data.isnull().sum()
# Out:
# temperature          0
# exhaust_vacuum       0
# amb_pressure         0
# r_humidity           0
# energy_production    0
# dtype: int64

# %%
#Summary odf data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9568 entries, 0 to 9567
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   temperature        9568 non-null   float64
#  1   exhaust_vacuum     9568 non-null   float64
#  2   amb_pressure       9568 non-null   float64
#  3   r_humidity         9568 non-null   float64
#  4   energy_production  9568 non-null   float64
# dtypes: float64(5)
# memory usage: 373.9 KB

# %%
# Statistically summary of data
data.describe()
# Out:
#        temperature  exhaust_vacuum  amb_pressure   r_humidity  \
# count  9568.000000     9568.000000   9568.000000  9568.000000
# mean     19.651231       54.305804   1013.259078    73.308978
# 4        15.14           49.64       1023.78       75.00             463.58

# %%
#No duplicated data shape
data_cleaned.shape
# Out:
# (9527, 5)

# %%
data_cleaned.describe()
# Out:
#        temperature  exhaust_vacuum  amb_pressure   r_humidity  \
# count  9527.000000     9527.000000   9527.000000  9527.000000
# mean     19.658225       54.293421   1013.237084    73.334951
# std       7.444397       12.686309      5.940526    14.607513
# min       1.810000       25.360000    992.890000    25.560000
# 25%      13.530000       41.740000   1009.085000    63.375000
# 50%      20.350000       52.080000   1012.920000    75.000000
# 75%      25.710000       66.510000   1017.200000    84.850000
# max      37.110000       81.560000   1033.300000   100.160000
#
#        energy_production
# count         9527.00000
# mean           454.33591
# std             17.03908
# min            420.26000
# 25%            439.75000
# 50%            451.52000
# 75%            468.36500
# max            495.76000

# %% [markdown]
# ## Data Visualization

# %%
data_cleaned.columns
# Out:
# Index(['temperature', 'exhaust_vacuum', 'amb_pressure', 'r_humidity',
#        'energy_production'],
#       dtype='object')

# %%
# checking data Distribution
sns.histplot(data_cleaned['temperature'],color='gray')
plt.show()

# %%
data_cleaned['temperature'].skew()
# Out:
# -0.1361069178515444

# %%
sns.histplot(data_cleaned['exhaust_vacuum'],color='gray')
plt.show()

# %%
data_cleaned['exhaust_vacuum'].skew()
# Out:
# 0.1968187812768364

# %%
sns.histplot(data_cleaned['amb_pressure'],color='gray')
plt.show()

# %%
sns.histplot(data_cleaned['r_humidity'],color='gray')
plt.show()

# %%
data_cleaned['r_humidity'].skew()
# Out:
# -0.43513848893895307

# %%
sns.histplot(data_cleaned['energy_production'],color='gray')
plt.show()

# %% [markdown]
# ## Checking Outlier

# %%
data_cleaned.plot(kind='box', subplots=True, figsize=(20,6))
plt.tight_layout()

# %%
#outlier remove
data_cleaned.drop(data_cleaned.index[data_cleaned['amb_pressure']>1029], inplace=True)
data_cleaned.drop(data_cleaned.index[data_cleaned['amb_pressure']<997], inplace=True)
data_cleaned.drop(data_cleaned.index[data_cleaned['r_humidity']<31], inplace=True)

# %%
data_cleaned.plot(kind='box', subplots=True, figsize=(20,6))
plt.tight_layout()

# %%
data_cleaned.shape
# Out:
# (9416, 5)

# %%
sns.set_style(style='darkgrid')
sns.pairplot(data_cleaned)

# %% [markdown]
# ## Checking Correlation

# %%
corr_matrix=data_cleaned.corr()
corr_matrix
# Out:
#                    temperature  exhaust_vacuum  amb_pressure  r_humidity  \
# temperature           1.000000        0.842231     -0.509005   -0.543672
# exhaust_vacuum        0.842231        1.000000     -0.417355   -0.310233
# amb_pressure         -0.509005       -0.417355      1.000000    0.107419
# r_humidity           -0.543672       -0.310233      0.107419    1.000000
# energy_production    -0.947242       -0.868760      0.521276    0.389424
#
#                    energy_production
# temperature                -0.947242
# exhaust_vacuum             -0.868760
# amb_pressure                0.521276
# r_humidity                  0.389424
# energy_production           1.000000

# %%
from sklearn import preprocessing

# %%
data_norm=preprocessing.normalize(data)
print(data_norm)
# Out:
# [[0.0085059  0.03420099 0.90204217 0.053306   0.42689147]
#  [0.01069519 0.03761084 0.90582255 0.08409585 0.4133817 ]
#  [0.01228345 0.03992343 0.90723954 0.07234572 0.41223508]
#  ...
#  [0.02776475 0.0512973  0.91684797 0.0512973  0.39160707]
#  [0.02073247 0.05953824 0.91998976 0.07237434 0.38000811]
#  [0.01584166 0.04395503 0.91110523 0.05682471 0.40555544]]

# %%
data_norm=pd.DataFrame(data_norm)
print(data_norm)
# Out:
#              0         1         2         3         4
# 0     0.008506  0.034201  0.902042  0.053306  0.426891
# 1     0.010695  0.037611  0.905823  0.084096  0.413382
# 2     0.012283  0.039923  0.907240  0.072346  0.412235
# 3     0.012205  0.048305  0.905506  0.070349  0.415484
# 4     0.013427  0.044025  0.907975  0.066516  0.411142
# ...        ...       ...       ...       ...       ...
# 9563  0.015421  0.044810  0.906771  0.073784  0.412404
# 9564  0.022222  0.058713  0.912432  0.047445  0.401592
# 9565  0.027765  0.051297  0.916848  0.051297  0.391607
# 9566  0.020732  0.059538  0.919990  0.072374  0.380008
# 9567  0.015842  0.043955  0.911105  0.056825  0.405555
#
# [9568 rows x 5 columns]

# %%
sns.pairplot(data_norm)
data_norm.corr()
# Out:
#           0         1         2         3         4
# 0  1.000000  0.853046  0.940404 -0.507330 -0.932134
# 1  0.853046  1.000000  0.827891 -0.284977 -0.880354
# 2  0.940404  0.827891  1.000000 -0.490010 -0.983720
# 3 -0.507330 -0.284977 -0.490010  1.000000  0.345422
# 4 -0.932134 -0.880354 -0.983720  0.345422  1.000000

# %%
data_norm.columns = data.columns
data_norm
# Out:
#       temperature  exhaust_vacuum  amb_pressure  r_humidity  energy_production
# 0        0.008506        0.034201      0.902042    0.053306           0.426891
# 1        0.010695        0.037611      0.905823    0.084096           0.413382
# 2        0.012283        0.039923      0.907240    0.072346           0.412235
# 3        0.012205        0.048305      0.905506    0.070349           0.415484
# 4        0.013427        0.044025      0.907975    0.066516           0.411142
# ...           ...             ...           ...         ...                ...
# 9563     0.015421        0.044810      0.906771    0.073784           0.412404
# 9564     0.022222        0.058713      0.912432    0.047445           0.401592
# 9565     0.027765        0.051297      0.916848    0.051297           0.391607
# 9566     0.020732        0.059538      0.919990    0.072374           0.380008
# 9567     0.015842        0.043955      0.911105    0.056825           0.405555
#
# [9568 rows x 5 columns]

# %%
x=data_norm.iloc[:,0:4]
y=data_norm.iloc[:,4]
print(x)
y
# Out:
#       temperature  exhaust_vacuum  amb_pressure  r_humidity
# 0        0.008506        0.034201      0.902042    0.053306
# 1        0.010695        0.037611      0.905823    0.084096
# 2        0.012283        0.039923      0.907240    0.072346
# 3        0.012205        0.048305      0.905506    0.070349
# 4        0.013427        0.044025      0.907975    0.066516
# ...           ...             ...           ...         ...
# 9563     0.015421        0.044810      0.906771    0.073784
# 9564     0.022222        0.058713      0.912432    0.047445
# 9565     0.027765        0.051297      0.916848    0.051297
# 9566     0.020732        0.059538      0.919990    0.072374
# 9567     0.015842        0.043955      0.911105    0.056825
#
# [9568 rows x 4 columns]
# 0       0.426891
# 1       0.413382
# 2       0.412235
# 3       0.415484
# 4       0.411142
#           ...
# 9563    0.412404
# 9564    0.401592
# 9565    0.391607
# 9566    0.380008
# 9567    0.405555
# Name: energy_production, Length: 9568, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.heatmap(corr_matrix,annot=True)
plt.show()
